# %% [markdown]
# # Version 3 - IGDT Base case v1
# ## w uncertainty of RES and w\o clearing fee
# ## Risk / Risk-Averse Scenario
# ### Author: Junhyeok Kim

# %%
# Import the library

import os
import pandas as pd
import numpy as np

from aggregator import aggregator
from gurobiMILP import gurobi_MILP
from draw_fig import Opt_Bid_Plot

import matplotlib.pyplot as plt
np.set_printoptions(formatter={'float': '{: 0.6f}'.format})

# %%
# Define the Variables
BASE_DIR = os.getcwd()
path = BASE_DIR

# Data generated from the date 221030 
wt_dataset = pd.read_excel(f"{path}/data/비중앙 실적.xlsx", 1, header=1)
wt_data = wt_dataset.iloc[-2, 1:-2].values
wt_profile = wt_data / np.max(wt_data)
wt_profile = wt_profile.astype(float)
wt_profile = np.maximum(wt_profile, 1e-6)

pv_dataset = pd.read_excel(f"{path}/data/비중앙 실적.xlsx", 2, header=1)
pv_data = pv_dataset.iloc[-2, 1:-2].values
pv_profile = pv_data / np.max(pv_data).astype(float)
pv_profile = pv_profile.astype(float)
pv_profile = np.maximum(pv_profile, 1e-6)

da_smp_dataset = pd.read_excel(f"{path}/data/smp_jeju_2022.xlsx", header=1)
da_smp_data = da_smp_dataset.loc[da_smp_dataset['구분']== 20221030]
da_smp_profile= da_smp_data.iloc[0,1:1+24].values
da_smp_profile = da_smp_profile.astype(float)

print("Display WT, PV, DA_SMP Profile")
display(wt_profile, pv_profile, da_smp_profile)
# Out:
# Display WT, PV, DA_SMP Profile
# array([ 0.251355,  0.290609,  0.392466,  0.452870,  0.474049,  0.541380,
#         0.713243,  0.707066,  0.772422,  0.544620,  0.079141,  0.126149,
#         0.108657,  0.122997,  0.196914,  0.573056,  0.869784,  1.000000,
#         0.998045,  0.834849,  0.742808,  0.654308,  0.603574,  0.747760])
# array([ 0.000423,  0.000407,  0.000374,  0.000363,  0.000358,  0.000363,
#         0.000477,  0.070437,  0.386254,  0.709651,  0.904545,  1.000000,
#         0.998997,  0.907256,  0.797912,  0.515076,  0.230750,  0.025176,
#         0.003318,  0.002179,  0.000001,  0.000092,  0.000461,  0.000455])
# array([ 258.300000,  232.600000,  213.100000,  207.750000,  213.250000,
#         213.250000,  213.100000,  212.800000,  212.650000,  213.760000,
#         204.700000,  211.140000,  211.140000,  210.510000,  208.000000,
#         207.590000,  210.510000,  257.690000,  283.370000,  258.120000,
#         258.160000,  257.800000,  258.280000,  257.040000])

# %%
# Define the Parameters

# case_dict: Generate various scenario
# res_var: Define the WT and PV as variables [True] or parameters [False]
# case:
    # case 1 : w/o uncertainty
    # case 2 : w uncertainty with +- 8% proportionally , robust (rise-averse)
    
    #res_var: Determine whether res (WT, PV) as variable or not
    #UNIT_TIME: 1 -> 1 hour
case_dict = {'res_var': True, 'case':2, 'UNIT_TIME': 1}
nTimeslot = int(24 / case_dict['UNIT_TIME'])
char_ess = {'initSOC':0.5, 'termSOC':0.5, 'minSOC':0.2, 'maxSOC':0.8, 'efficiency':0.95}

model_dict = {'nVPP':1, 'da_smp': da_smp_profile, 'nTimeslot': nTimeslot}

# Once, set te PV, WT, SMP uncertainties identically in each time (PV: 5%, WT: 10%, SMP: 10%)
uncertainty_dict = {'pv': np.ones(nTimeslot)*0.05 , 'wt': np.ones(nTimeslot)*0.10, 'smp':np.ones(nTimeslot)*0.10}


if case_dict['case']==2:
    
    model_dict['uncertainty'] = uncertainty_dict
    case_dict['bid_type'] = 'risky'
    
elif case_dict['case'] == 1:
    
    uncertainty_dict = {'pv': np.zeros(nTimeslot), 'wt': np.zeros(nTimeslot), 'smp':np.zeros(nTimeslot)}
    model_dict['uncertainty'] = uncertainty_dict
    
# Set Up VPP  #Unit: kW

vpp_list = []
for i in range(model_dict['nVPP']):
    nGen_dict = {'WT':1,'PV':2, 'ESS':1}
    
    wt_list = [1000]
    pv_list = [3000, 2000]
    ess_list = []
    capacity_list = [3000] 
    max_list = [wt_list, pv_list, ess_list, capacity_list]
    
    agg_dict = {'name': f'cvpp{i+1}', 'code': f'xds{i+1}', 'gen':nGen_dict,
                'profile': [wt_profile, pv_profile]}
    vpp_list.append(aggregator(agg_dict, char_ess, model_dict))
    vpp_list[i].set_der_power(max_list)
vpp_list[0].get_res_table()
# Out:
#          name type  number  min_power  max_power  capacity
# 0   WT1_cvpp1   WT       1          0       1000       NaN
# 1   PV2_cvpp1   PV       2          0       3000       NaN
# 2   PV3_cvpp1   PV       3          0       2000       NaN
# 3  ESS4_cvpp1  ESS       4      -1000       1000    3000.0

# %% [markdown]
# ## Run the base case (deterministic model)
# ## w/o uncertainty

# %%
# Gurobi Optimization Model
opt_bid = gurobi_MILP('opt bid', vpp_list[0], model_dict, case_dict)
sol, obj, P_dict, U_dict = opt_bid.optimize()
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Set parameter FeasibilityTol to value 0.0001
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-12400, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 217 rows, 288 columns and 1680 nonzeros
# Model fingerprint: 0x1316194d
# Variable types: 240 continuous, 48 integer (48 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+03]
#   Objective range  [2e+02, 3e+02]
#   Bounds range     [5e-02, 7e+03]
#   RHS range        [2e-03, 3e+03]
# Found heuristic solution: objective 9250706.0350
# Presolve removed 122 rows and 214 columns
# Presolve time: 0.00s
# Presolved: 95 rows, 74 columns, 1080 nonzeros
# Found heuristic solution: objective 1.054122e+07
# Variable types: 50 continuous, 24 integer (24 binary)
#
# Root relaxation: objective 1.061390e+07, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.061390e+07 1.0614e+07  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.06139e+07 1.05412e+07 9.25071e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.061390468679e+07, best bound 1.061390468679e+07, gap 0.0000%
# Optimization Duration Time: 0.017000198364257812
# Optimal Solution:

# %%
obj
# Out:
# 10613904.686791098

# %%
P_dict, U_dict = opt_bid.get_sol()
display(P_dict)

#P_dict: The results of the variables
# Out:
# {'bid': array([ 1133.710105,  321.804573,  433.676691,  500.064302,  523.332628,
#          597.424966,  787.072269,  1147.564040,  2877.498581,  4324.747615,
#          3835.916853,  5388.764094,  5364.257855,  4898.388850,
#          4405.642425,  2439.774356,  2168.198316,  1232.172131,
#          1970.267066,  929.775547,  817.094295,  720.222916,  666.350838,
#          824.926730]),
#  'essDis': array([[ 855.000000,  0.000000,  0.000000,  0.000000,  0.000000,
#           0.000000,  0.000000,  0.000000,  0.000000,  0.000000,  0.000000,
#           0.000000,  0.000000,  0.000000,  0.000000,  0.000000,  0.000000,
#           0.000000,  855.000000,  0.000000,  0.000000,  0.000000,
#           0.000000,  0.000000]]),
#  'essChg': array([[ 0.000000,  0.000000,  0.000000,  0.000000,  0.000000,  0.000000,
#           0.000000,  0.000000,  0.000000,  0.000000,  1000.000000,
#           0.000000,  0.000000,  0.000000,  0.000000,  894.736842,
#           0.000000,  0.000000,  0.000000,  0.000000,  0.000000,  0.000000,
#           0.000000,  0.000000]]),
#  'wt': array([[ 276.490160,  319.670010,  431.712893,  498.157426,  521.454213,
#           595.518090,  784.567715,  777.772373,  849.663881,  599.081632,
#           87.055287,  138.764094,  119.523110,  135.296865,  216.605539,
#           630.361608,  956.762752,  1100.000000,  1097.849033,
#           918.334290,  817.089045,  719.739082,  663.931667,  822.536020]]),
#  'pv': array([[ 1.331967,  1.280738,  1.178279,  1.144126,  1.127049,  1.144126,
#           1.502732,  221.875000,  1216.700820,  2235.399590,  2849.316940,
#           3150.000000,  3146.840847,  2857.855191,  2513.422131,
#           1622.489754,  726.861339,  79.303279,  10.450820,  6.864754,
#           0.003150,  0.290301,  1.451503,  1.434426],
#         [ 0.887978,  0.853825,  0.785519,  0.762750,  0.751366,  0.762750,
#           1.001821,  147.916667,  811.133880,  1490.266393,  1899.544627,
#           2100.000000,  2097.893898,  1905.236794,  1675.614754,
#           1081.659836,  484.574226,  52.868852,  6.967213,  4.576503,
#           0.002100,  0.193534,  0.967668,  0.956284]]),
#  'wt_uncertainty': array([[ 0.100000,  0.100000,  0.100000,  0.100000,  0.100000,  0.100000,
#           0.100000,  0.100000,  0.100000,  0.100000,  0.100000,  0.100000,
#           0.100000,  0.100000,  0.100000,  0.100000,  0.100000,  0.100000,
#           0.100000,  0.100000,  0.100000,  0.100000,  0.100000,  0.100000]]),
#  'pv_uncertainty': array([[ 0.050000,  0.050000,  0.050000,  0.050000,  0.050000,  0.050000,
#           0.050000,  0.050000,  0.050000,  0.050000,  0.050000,  0.050000,
#           0.050000,  0.050000,  0.050000,  0.050000,  0.050000,  0.050000,
#           0.050000,  0.050000,  0.050000,  0.050000,  0.050000,  0.050000],
#         [ 0.050000,  0.050000,  0.050000,  0.050000,  0.050000,  0.050000,
#           0.050000,  0.050000,  0.050000,  0.050000,  0.050000,  0.050000,
#           0.050000,  0.050000,  0.050000,  0.050000,  0.050000,  0.050000,
#           0.050000,  0.050000,  0.050000,  0.050000,  0.050000,  0.050000]])}

# %%
# Draw the Plots

bid_plot = Opt_Bid_Plot(vpp_list, opt_bid, model_dict, case_dict, path)
bid_plot.make_plot(P_dict)

# %% [markdown]
# ## Run the Risk-Averse Scenario
# ## opt_bid_risk_averse Sets (maximize the profile with considering uncertainty robustness)
#
# ### Uncertainty -> PV: +- 5%, WT: +-10%, SMP: +- 10% for all timeslots
# ### Set this on gurobi_MILP -> add_Variables

# %%
case_dict['bid_type'] = 'risk_averse'
# Gurobi Optimization Model
opt_bid_risk_averse = gurobi_MILP(f"opt_bid_{case_dict['bid_type']}", vpp_list[0], model_dict, case_dict)
opt_bid_risk_averse.add_Parameters()
opt_bid_risk_averse.add_Variables()
opt_bid_risk_averse.add_bid_constraints()
opt_bid_risk_averse.add_res_constraints()

opt_bid_risk_averse.add_ess_contraints()
opt_bid_risk_averse.set_Objectives()

mip_gap = 0.0001
feas_tol = 1e-4
sol_risk_averse, obj_risk_averse = opt_bid_risk_averse.solve([mip_gap, feas_tol])
# Out:
# Set parameter FeasibilityTol to value 0.0001
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 217 rows, 288 columns and 1680 nonzeros
# Model fingerprint: 0xda525d06
# Variable types: 240 continuous, 48 integer (48 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+03]
#   Objective range  [2e+02, 3e+02]
#   Bounds range     [5e-02, 7e+03]
#   RHS range        [2e-03, 3e+03]
# Found heuristic solution: objective 9250706.0350
# Presolve removed 122 rows and 214 columns
# Presolve time: 0.00s
# Presolved: 95 rows, 74 columns, 1080 nonzeros
# Variable types: 50 continuous, 24 integer (24 binary)
#
# Root relaxation: objective 9.323395e+06, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    9323395.4640 9323395.46  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 9.3234e+06 9.25071e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.323395463982e+06, best bound 9.323395463982e+06, gap 0.0000%
# Optimization Duration Time: 0.019010066986083984
# Optimal Solution:

# %%
# Draw the Plots
print(f"opt_bid_{case_dict['bid_type']}")
P_dict_risk_averse, U_dict_risk_averse = opt_bid_risk_averse.get_sol()
display(P_dict_risk_averse)
# Out:
# opt_bid_risk_averse
# {'bid': array([ 1083.227744,  263.479461,  354.996409,  409.308618,  428.343875,
#          488.967343,  644.185064,  970.932627,  2529.887124,  3860.998350,
#          3367.816089,  4863.534259,  4843.027833,  4420.161612,
#          3967.303705,  2067.625098,  1878.866637,  1019.584309,
#          1768.999291,  761.716032,  668.532150,  589.315186,  545.405593,
#          675.147040]),
#  'essDis': array([[ 855.000000,  0.000000,  0.000000,  0.000000,  0.000000,
#           0.000000,  0.000000,  0.000000,  0.000000,  0.000000,  0.000000,
#           0.000000,  0.000000,  0.000000,  0.000000,  0.000000,  0.000000,
#           0.000000,  855.000000,  0.000000,  0.000000,  0.000000,
#           0.000000,  0.000000]]),
#  'essChg': array([[ 0.000000,  0.000000,  0.000000,  0.000000,  0.000000,  0.000000,
#           0.000000,  0.000000,  0.000000,  0.000000,  1000.000000,
#           0.000000,  0.000000,  0.000000,  0.000000,  894.736842,
#           0.000000,  0.000000,  0.000000,  0.000000,  0.000000,  0.000000,
#           0.000000,  0.000000]]),
#  'wt': array([[ 226.219222,  261.548190,  353.219640,  407.583349,  426.644356,
#           487.242074,  641.919040,  636.359214,  695.179539,  490.157699,
#           71.227053,  113.534259,  97.791635,  110.697435,  177.222714,
#           515.750406,  782.805888,  900.000000,  898.240118,  751.364419,
#           668.527400,  588.877431,  543.216819,  672.984016]]),
#  'pv': array([[ 1.205113,  1.158763,  1.066062,  1.035161,  1.019711,  1.035161,
#           1.359615,  200.744048,  1100.824551,  2022.504391,  2577.953422,
#           2850.000000,  2847.141719,  2585.678506,  2274.048595,
#           1467.966920,  657.636449,  71.750585,  9.455504,  6.210968,
#           0.002850,  0.262653,  1.313264,  1.297814],
#         [ 0.803409,  0.772508,  0.710708,  0.690108,  0.679807,  0.690108,
#           0.906410,  133.829365,  733.883034,  1348.336261,  1718.635615,
#           1900.000000,  1898.094479,  1723.785671,  1516.032397,
#           978.644614,  438.424300,  47.833724,  6.303669,  4.140645,
#           0.001900,  0.175102,  0.875510,  0.865209]]),
#  'wt_uncertainty': array([[-0.100000, -0.100000, -0.100000, -0.100000, -0.100000, -0.100000,
#          -0.100000, -0.100000, -0.100000, -0.100000, -0.100000, -0.100000,
#          -0.100000, -0.100000, -0.100000, -0.100000, -0.100000, -0.100000,
#          -0.100000, -0.100000, -0.100000, -0.100000, -0.100000, -0.100000]]),
#  'pv_uncertainty': array([[-0.050000, -0.050000, -0.050000, -0.050000, -0.050000, -0.050000,
#          -0.050000, -0.050000, -0.050000, -0.050000, -0.050000, -0.050000,
#          -0.050000, -0.050000, -0.050000, -0.050000, -0.050000, -0.050000,
#          -0.050000, -0.050000, -0.050000, -0.050000, -0.050000, -0.050000],
#         [-0.050000, -0.050000, -0.050000, -0.050000, -0.050000, -0.050000,
#          -0.050000, -0.050000, -0.050000, -0.050000, -0.050000, -0.050000,
#          -0.050000, -0.050000, -0.050000, -0.050000, -0.050000, -0.050000,
#          -0.050000, -0.050000, -0.050000, -0.050000, -0.050000, -0.050000]])}

# %%
# Draw the Plots
bid_plot_risk_averse = Opt_Bid_Plot(vpp_list, opt_bid_risk_averse, model_dict, case_dict, path)
bid_plot.make_plot(P_dict_risk_averse)

# %%
# Check the RES constraint that the method (add_Varaibles) in gurobi_MILP 
# True: add_Variables method - while defining lb, ub in defining variables
# Flase: add_res_contraints method 
check_set = opt_bid_risk_averse.check_res_var_sol(True)
# Out:
# **********
# Check_RES_Constaraint_Solution
# Check_RES_Constaraint_Solution
# Check_RES_Constaraint_Solution
# **********
# ***********
# P_wt[i,step], lb, ub, max_power, profile, uncert
# var_PWT_lb_ub[0,0]_maxpower_profile_Puncertainty: 226.2192215271765 0.0 1100.0 1000 0.25135469058575166 -0.1
# var_PWT_lb_ub[0,1]_maxpower_profile_Puncertainty: 261.5481900166357 0.0 1100.0 1000 0.2906091000184841 -0.1
# var_PWT_lb_ub[0,2]_maxpower_profile_Puncertainty: 353.219639851738 0.0 1100.0 1000 0.3924662665019311 -0.1
# var_PWT_lb_ub[0,3]_maxpower_profile_Puncertainty: 407.5833487367571 0.0 1100.0 1000 0.4528703874852857 -0.1
# var_PWT_lb_ub[0,4]_maxpower_profile_Puncertainty: 426.6443560233872 0.0 1100.0 1000 0.47404928447043027 -0.1
# var_PWT_lb_ub[0,5]_maxpower_profile_Puncertainty: 487.24207372240767 0.0 1100.0 1000 0.5413800819137863 -0.1
# var_PWT_lb_ub[0,6]_maxpower_profile_Puncertainty: 641.9190396046347 0.0 1100.0 1000 0.713243377338483 -0.1
# var_PWT_lb_ub[0,7]_maxpower_profile_Puncertainty: 636.3592143281026 0.0 1100.0 1000 0.7070657936978918 -0.1
# var_PWT_lb_ub[0,8]_maxpower_profile_Puncertainty: 695.1795390647042 0.0 1100.0 1000 0.7724217100718934 -0.1
# var_PWT_lb_ub[0,9]_maxpower_profile_Puncertainty: 490.157698631203 0.0 1100.0 1000 0.5446196651457812 -0.1
# var_PWT_lb_ub[0,10]_maxpower_profile_Puncertainty: 71.2270529521067 0.0 1100.0 1000 0.07914116994678523 -0.1
# var_PWT_lb_ub[0,11]_maxpower_profile_Puncertainty: 113.5342588358903 0.0 1100.0 1000 0.12614917648432256 -0.1
# var_PWT_lb_ub[0,12]_maxpower_profile_Puncertainty: 97.79163545446585 0.0 1100.0 1000 0.10865737272718429 -0.1
# var_PWT_lb_ub[0,13]_maxpower_profile_Puncertainty: 110.69743460030547 0.0 1100.0 1000 0.12299714955589497 -0.1
# var_PWT_lb_ub[0,14]_maxpower_profile_Puncertainty: 177.22271405084103 0.0 1100.0 1000 0.1969141267231567 -0.1
# var_PWT_lb_ub[0,15]_maxpower_profile_Puncertainty: 515.7504061639637 0.0 1100.0 1000 0.5730560068488486 -0.1
# var_PWT_lb_ub[0,16]_maxpower_profile_Puncertainty: 782.805887674991 0.0 1100.0 1000 0.8697843196388789 -0.1
# var_PWT_lb_ub[0,17]_maxpower_profile_Puncertainty: 900.0 0.0 1100.0 1000 1.0 -0.1
# var_PWT_lb_ub[0,18]_maxpower_profile_Puncertainty: 898.2401182982946 0.0 1100.0 1000 0.998044575886994 -0.1
# var_PWT_lb_ub[0,19]_maxpower_profile_Puncertainty: 751.3644190639258 0.0 1100.0 1000 0.8348493545154732 -0.1
# var_PWT_lb_ub[0,20]_maxpower_profile_Puncertainty: 668.5274002587776 0.0 1100.0 1000 0.7428082225097528 -0.1
# var_PWT_lb_ub[0,21]_maxpower_profile_Puncertainty: 588.8774309034837 0.0 1100.0 1000 0.6543082565594264 -0.1
# var_PWT_lb_ub[0,22]_maxpower_profile_Puncertainty: 543.2168185930675 0.0 1100.0 1000 0.6035742428811861 -0.1
# var_PWT_lb_ub[0,23]_maxpower_profile_Puncertainty: 672.9840161103598 0.0 1100.0 1000 0.7477600179003998 -0.1
# ***********
# ***********
# P_pv[i,step], lb, ub, max_power, profile, uncert
# var_PPV_lb_ub[0,0]_maxpower_profile_Puncertainty: 1.205113192818111 0.0 3150.0 3000 0.00042284673432214416 -0.05
# var_PPV_lb_ub[0,1]_maxpower_profile_Puncertainty: 1.1587626854020296 0.0 3150.0 3000 0.0004065833983866771 -0.05
# var_PPV_lb_ub[0,2]_maxpower_profile_Puncertainty: 1.0660616705698673 0.0 3150.0 3000 0.0003740567265157429 -0.05
# var_PPV_lb_ub[0,3]_maxpower_profile_Puncertainty: 1.0351613322924798 0.0 3150.0 3000 0.00036321450255876484 -0.05
# var_PPV_lb_ub[0,4]_maxpower_profile_Puncertainty: 1.019711163153786 0.0 3150.0 3000 0.0003577933905802758 -0.05
# var_PPV_lb_ub[0,5]_maxpower_profile_Puncertainty: 1.0351613322924798 0.0 3150.0 3000 0.00036321450255876484 -0.05
# var_PPV_lb_ub[0,6]_maxpower_profile_Puncertainty: 1.3596148842050482 0.0 3150.0 3000 0.0004770578541070344 -0.05
# var_PPV_lb_ub[0,7]_maxpower_profile_Puncertainty: 200.7440476190476 0.0 3150.0 3000 0.07043650793650794 -0.05
# var_PPV_lb_ub[0,8]_maxpower_profile_Puncertainty: 1100.824551131928 0.0 3150.0 3000 0.3862542284673432 -0.05
# var_PPV_lb_ub[0,9]_maxpower_profile_Puncertainty: 2022.5043911007026 0.0 3150.0 3000 0.7096506635441062 -0.05
# var_PPV_lb_ub[0,10]_maxpower_profile_Puncertainty: 2577.9534218058807 0.0 3150.0 3000 0.9045450602827652 -0.05
# var_PPV_lb_ub[0,11]_maxpower_profile_Puncertainty: 2850.0 0.0 3150.0 3000 1.0 -0.05
# var_PPV_lb_ub[0,12]_maxpower_profile_Puncertainty: 2847.1417187093416 0.0 3150.0 3000 0.9989970942839795 -0.05
# var_PPV_lb_ub[0,13]_maxpower_profile_Puncertainty: 2585.6785063752272 0.0 3150.0 3000 0.9072556162720097 -0.05
# var_PPV_lb_ub[0,14]_maxpower_profile_Puncertainty: 2274.048594847775 0.0 3150.0 3000 0.797911787665886 -0.05
# var_PPV_lb_ub[0,15]_maxpower_profile_Puncertainty: 1467.9669203747071 0.0 3150.0 3000 0.515076112412178 -0.05
# var_PPV_lb_ub[0,16]_maxpower_profile_Puncertainty: 657.6364493884985 0.0 3150.0 3000 0.23074963136438545 -0.05
# var_PPV_lb_ub[0,17]_maxpower_profile_Puncertainty: 71.75058548009368 0.0 3150.0 3000 0.025175644028103045 -0.05
# var_PPV_lb_ub[0,18]_maxpower_profile_Puncertainty: 9.455503512880563 0.0 3150.0 3000 0.003317720530835285 -0.05
# var_PPV_lb_ub[0,19]_maxpower_profile_Puncertainty: 6.210967993754879 0.0 3150.0 3000 0.0021792870153525892 -0.05
# var_PPV_lb_ub[0,20]_maxpower_profile_Puncertainty: 0.00285 0.0 3150.0 3000 1e-06 -0.05
# var_PPV_lb_ub[0,21]_maxpower_profile_Puncertainty: 0.26265287535779336 0.0 3150.0 3000 9.215890363431347e-05 -0.05
# var_PPV_lb_ub[0,22]_maxpower_profile_Puncertainty: 1.313264376788967 0.0 3150.0 3000 0.00046079451817156733 -0.05
# var_PPV_lb_ub[0,23]_maxpower_profile_Puncertainty: 1.2978142076502732 0.0 3150.0 3000 0.0004553734061930783 -0.05
# ***********
# ***********
# P_pv[i,step], lb, ub, max_power, profile, uncert
# var_PPV_lb_ub[1,0]_maxpower_profile_Puncertainty: 0.8034087952120739 0.0 2100.0 2000 0.00042284673432214416 -0.05
# var_PPV_lb_ub[1,1]_maxpower_profile_Puncertainty: 0.7725084569346864 0.0 2100.0 2000 0.0004065833983866771 -0.05
# var_PPV_lb_ub[1,2]_maxpower_profile_Puncertainty: 0.7107077803799116 0.0 2100.0 2000 0.0003740567265157429 -0.05
# var_PPV_lb_ub[1,3]_maxpower_profile_Puncertainty: 0.6901075548616532 0.0 2100.0 2000 0.00036321450255876484 -0.05
# var_PPV_lb_ub[1,4]_maxpower_profile_Puncertainty: 0.6798074421025241 0.0 2100.0 2000 0.0003577933905802758 -0.05
# var_PPV_lb_ub[1,5]_maxpower_profile_Puncertainty: 0.6901075548616532 0.0 2100.0 2000 0.00036321450255876484 -0.05
# var_PPV_lb_ub[1,6]_maxpower_profile_Puncertainty: 0.9064099228033654 0.0 2100.0 2000 0.0004770578541070344 -0.05
# var_PPV_lb_ub[1,7]_maxpower_profile_Puncertainty: 133.8293650793651 0.0 2100.0 2000 0.07043650793650794 -0.05
# var_PPV_lb_ub[1,8]_maxpower_profile_Puncertainty: 733.8830340879521 0.0 2100.0 2000 0.3862542284673432 -0.05
# var_PPV_lb_ub[1,9]_maxpower_profile_Puncertainty: 1348.3362607338017 0.0 2100.0 2000 0.7096506635441062 -0.05
# var_PPV_lb_ub[1,10]_maxpower_profile_Puncertainty: 1718.6356145372538 0.0 2100.0 2000 0.9045450602827652 -0.05
# var_PPV_lb_ub[1,11]_maxpower_profile_Puncertainty: 1900.0 0.0 2100.0 2000 1.0 -0.05
# var_PPV_lb_ub[1,12]_maxpower_profile_Puncertainty: 1898.0944791395611 0.0 2100.0 2000 0.9989970942839795 -0.05
# var_PPV_lb_ub[1,13]_maxpower_profile_Puncertainty: 1723.7856709168184 0.0 2100.0 2000 0.9072556162720097 -0.05
# var_PPV_lb_ub[1,14]_maxpower_profile_Puncertainty: 1516.0323965651833 0.0 2100.0 2000 0.797911787665886 -0.05
# var_PPV_lb_ub[1,15]_maxpower_profile_Puncertainty: 978.6446135831382 0.0 2100.0 2000 0.515076112412178 -0.05
# var_PPV_lb_ub[1,16]_maxpower_profile_Puncertainty: 438.4242995923323 0.0 2100.0 2000 0.23074963136438545 -0.05
# var_PPV_lb_ub[1,17]_maxpower_profile_Puncertainty: 47.83372365339578 0.0 2100.0 2000 0.025175644028103045 -0.05
# var_PPV_lb_ub[1,18]_maxpower_profile_Puncertainty: 6.3036690085870415 0.0 2100.0 2000 0.003317720530835285 -0.05
# var_PPV_lb_ub[1,19]_maxpower_profile_Puncertainty: 4.14064532916992 0.0 2100.0 2000 0.0021792870153525892 -0.05
# var_PPV_lb_ub[1,20]_maxpower_profile_Puncertainty: 0.0019 0.0 2100.0 2000 1e-06 -0.05
# var_PPV_lb_ub[1,21]_maxpower_profile_Puncertainty: 0.1751019169051956 0.0 2100.0 2000 9.215890363431347e-05 -0.05
# var_PPV_lb_ub[1,22]_maxpower_profile_Puncertainty: 0.8755095845259779 0.0 2100.0 2000 0.00046079451817156733 -0.05
# var_PPV_lb_ub[1,23]_maxpower_profile_Puncertainty: 0.8652094717668488 0.0 2100.0 2000 0.0004553734061930783 -0.05
# ***********

# %%
# Check the RES constraint that the method (add_Varaibles) in gurobi_MILP  
lhs, rhs = opt_bid_risk_averse.check_res_const_sol()
# Out:
# Risk_averse_Check_res_const_sol
# Risk_averse_Check_res_const_sol
# Risk_averse_Check_res_const_sol
# risk_averse-check_res_const
# (LHS, RHS) - WT + PV
# (226.2192215271765, 276.4901596443268)
# (1.205113192818111, 1.3319672131147542)
# (0.8034087952120739, 0.8879781420765027)
# (261.5481900166357, 319.67001002033254)
# (1.1587626854020296, 1.2807377049180328)
# (0.7725084569346864, 0.8538251366120219)
# (353.219639851738, 431.71289315212425)
# (1.0660616705698673, 1.1782786885245902)
# (0.7107077803799116, 0.7855191256830601)
# (407.5833487367571, 498.15742623381425)
# (1.0351613322924798, 1.1441256830601092)
# (0.6901075548616532, 0.7627504553734061)
# (426.6443560233872, 521.4542129174733)
# (1.019711163153786, 1.1270491803278688)
# (0.6798074421025241, 0.7513661202185792)
# (487.24207372240767, 595.5180901051649)
# (1.0351613322924798, 1.1441256830601092)
# (0.6901075548616532, 0.7627504553734061)
# (641.9190396046347, 784.5677150723312)
# (1.3596148842050482, 1.5027322404371584)
# (0.9064099228033654, 1.0018214936247722)
# (636.3592143281026, 777.772373067681)
# (200.7440476190476, 221.875)
# (133.8293650793651, 147.91666666666666)
# (695.1795390647042, 849.6638810790828)
# (1100.824551131928, 1216.700819672131)
# (733.8830340879521, 811.1338797814207)
# (490.157698631203, 599.0816316603593)
# (2022.5043911007026, 2235.3995901639346)
# (1348.3362607338017, 1490.266393442623)
# (71.2270529521067, 87.05528694146375)
# (2577.9534218058807, 2849.3169398907103)
# (1718.6356145372538, 1899.544626593807)
# (113.5342588358903, 138.76409413275482)
# (2850.0, 3150.0)
# (1900.0, 2100.0)
# (97.79163545446585, 119.52310999990272)
# (2847.1417187093416, 3146.8408469945357)
# (1898.0944791395611, 2097.893897996357)
# (110.69743460030547, 135.29686451148447)
# (2585.6785063752272, 2857.8551912568305)
# (1723.7856709168184, 1905.2367941712203)
# (177.22271405084103, 216.60553939547236)
# (2274.048594847775, 2513.4221311475408)
# (1516.0323965651833, 1675.6147540983607)
# (515.7504061639637, 630.3616075337335)
# (1467.9669203747071, 1622.4897540983607)
# (978.6446135831382, 1081.6598360655737)
# (782.805887674991, 956.7627516027668)
# (657.6364493884985, 726.8613387978141)
# (438.4242995923323, 484.5742258652094)
# (900.0, 1100.0)
# (71.75058548009368, 79.30327868852459)
# (47.83372365339578, 52.868852459016395)
# (898.2401182982946, 1097.8490334756934)
# (9.455503512880563, 10.450819672131148)
# (6.3036690085870415, 6.967213114754099)
# (751.3644190639258, 918.3342899670205)
# (6.210967993754879, 6.864754098360656)
# (4.14064532916992, 4.576502732240438)
# (668.5274002587776, 817.089044760728)
# (0.00285, 0.00315)
# (0.0019, 0.0021)
# (588.8774309034837, 719.739082215369)
# (0.26265287535779336, 0.29030054644808745)
# (0.1751019169051956, 0.1935336976320583)
# (543.2168185930675, 663.9316671693048)
# (1.313264376788967, 1.451502732240437)
# (0.8755095845259779, 0.9676684881602914)
# (672.9840161103598, 822.5360196904398)
# (1.2978142076502732, 1.4344262295081966)
# (0.8652094717668488, 0.9562841530054644)

# %%
# Check the bid contraints that the method (add_bid_constraints) in gurobi_MILP 
lhs_bid, rhs_bid = opt_bid_risk_averse.check_bid_const_sol()
# Out:
# check_bid_const_sol
# check_bid_const_sol
# check_bid_const_sol
# (1083.227743515207, 1083.227743515207)
# (263.4794611589724, 263.47946115897247)
# (354.99640930268777, 354.99640930268777)
# (409.30861762391123, 409.30861762391123)
# (428.3438746286435, 428.3438746286435)
# (488.9673426095618, 488.9673426095618)
# (644.1850644116431, 644.1850644116431)
# (970.9326270265152, 970.9326270265152)
# (2529.8871242845844, 2529.8871242845844)
# (3860.9983504657075, 3860.9983504657075)
# (3367.816089295241, 3367.816089295241)
# (4863.53425883589, 4863.534258835891)
# (4843.027833303368, 4843.027833303368)
# (4420.161611892351, 4420.161611892351)
# (3967.3037054637994, 3967.3037054637994)
# (2067.625098016545, 2067.6250980165455)
# (1878.8666366558218, 1878.8666366558218)
# (1019.5843091334895, 1019.5843091334895)
# (1768.9992908197623, 1768.9992908197623)
# (761.7160323868505, 761.7160323868507)
# (668.5321502587775, 668.5321502587775)
# (589.3151856957468, 589.3151856957468)
# (545.4055925543825, 545.4055925543825)
# (675.147039789777, 675.147039789777)

# %%
# Check the RES constraint that the method (add_res_constraints) in gurobi_MILP 
# True: add_Variables method, 
# Flase: add_res_contraints method 
check_set_const = opt_bid_risk_averse.check_res_var_sol(False)
# Out:
# **********
# Check_RES_Constaraint_Solution
# Check_RES_Constaraint_Solution
# Check_RES_Constaraint_Solution
# **********
# ***********
# P_wt[i,step], lb, ub, max_power, profile, uncert
# var_PWT_lb_ub[0,0]_maxpower_profile_Puncertainty: 226.2192215271765 0.0 900.0 1000 0.25135469058575166 -0.1
# var_PWT_lb_ub[0,1]_maxpower_profile_Puncertainty: 261.5481900166357 0.0 900.0 1000 0.2906091000184841 -0.1
# var_PWT_lb_ub[0,2]_maxpower_profile_Puncertainty: 353.219639851738 0.0 900.0 1000 0.3924662665019311 -0.1
# var_PWT_lb_ub[0,3]_maxpower_profile_Puncertainty: 407.5833487367571 0.0 900.0 1000 0.4528703874852857 -0.1
# var_PWT_lb_ub[0,4]_maxpower_profile_Puncertainty: 426.6443560233872 0.0 900.0 1000 0.47404928447043027 -0.1
# var_PWT_lb_ub[0,5]_maxpower_profile_Puncertainty: 487.24207372240767 0.0 900.0 1000 0.5413800819137863 -0.1
# var_PWT_lb_ub[0,6]_maxpower_profile_Puncertainty: 641.9190396046347 0.0 900.0 1000 0.713243377338483 -0.1
# var_PWT_lb_ub[0,7]_maxpower_profile_Puncertainty: 636.3592143281026 0.0 900.0 1000 0.7070657936978918 -0.1
# var_PWT_lb_ub[0,8]_maxpower_profile_Puncertainty: 695.1795390647042 0.0 900.0 1000 0.7724217100718934 -0.1
# var_PWT_lb_ub[0,9]_maxpower_profile_Puncertainty: 490.157698631203 0.0 900.0 1000 0.5446196651457812 -0.1
# var_PWT_lb_ub[0,10]_maxpower_profile_Puncertainty: 71.2270529521067 0.0 900.0 1000 0.07914116994678523 -0.1
# var_PWT_lb_ub[0,11]_maxpower_profile_Puncertainty: 113.5342588358903 0.0 900.0 1000 0.12614917648432256 -0.1
# var_PWT_lb_ub[0,12]_maxpower_profile_Puncertainty: 97.79163545446585 0.0 900.0 1000 0.10865737272718429 -0.1
# var_PWT_lb_ub[0,13]_maxpower_profile_Puncertainty: 110.69743460030547 0.0 900.0 1000 0.12299714955589497 -0.1
# var_PWT_lb_ub[0,14]_maxpower_profile_Puncertainty: 177.22271405084103 0.0 900.0 1000 0.1969141267231567 -0.1
# var_PWT_lb_ub[0,15]_maxpower_profile_Puncertainty: 515.7504061639637 0.0 900.0 1000 0.5730560068488486 -0.1
# var_PWT_lb_ub[0,16]_maxpower_profile_Puncertainty: 782.805887674991 0.0 900.0 1000 0.8697843196388789 -0.1
# var_PWT_lb_ub[0,17]_maxpower_profile_Puncertainty: 900.0 0.0 900.0 1000 1.0 -0.1
# var_PWT_lb_ub[0,18]_maxpower_profile_Puncertainty: 898.2401182982946 0.0 900.0 1000 0.998044575886994 -0.1
# var_PWT_lb_ub[0,19]_maxpower_profile_Puncertainty: 751.3644190639258 0.0 900.0 1000 0.8348493545154732 -0.1
# var_PWT_lb_ub[0,20]_maxpower_profile_Puncertainty: 668.5274002587776 0.0 900.0 1000 0.7428082225097528 -0.1
# var_PWT_lb_ub[0,21]_maxpower_profile_Puncertainty: 588.8774309034837 0.0 900.0 1000 0.6543082565594264 -0.1
# var_PWT_lb_ub[0,22]_maxpower_profile_Puncertainty: 543.2168185930675 0.0 900.0 1000 0.6035742428811861 -0.1
# var_PWT_lb_ub[0,23]_maxpower_profile_Puncertainty: 672.9840161103598 0.0 900.0 1000 0.7477600179003998 -0.1
# ***********
# ***********
# P_pv[i,step], lb, ub, max_power, profile, uncert
# var_PPV_lb_ub[0,0]_maxpower_profile_Puncertainty: 1.205113192818111 0.0 2850.0 3000 0.00042284673432214416 -0.05
# var_PPV_lb_ub[0,1]_maxpower_profile_Puncertainty: 1.1587626854020296 0.0 2850.0 3000 0.0004065833983866771 -0.05
# var_PPV_lb_ub[0,2]_maxpower_profile_Puncertainty: 1.0660616705698673 0.0 2850.0 3000 0.0003740567265157429 -0.05
# var_PPV_lb_ub[0,3]_maxpower_profile_Puncertainty: 1.0351613322924798 0.0 2850.0 3000 0.00036321450255876484 -0.05
# var_PPV_lb_ub[0,4]_maxpower_profile_Puncertainty: 1.019711163153786 0.0 2850.0 3000 0.0003577933905802758 -0.05
# var_PPV_lb_ub[0,5]_maxpower_profile_Puncertainty: 1.0351613322924798 0.0 2850.0 3000 0.00036321450255876484 -0.05
# var_PPV_lb_ub[0,6]_maxpower_profile_Puncertainty: 1.3596148842050482 0.0 2850.0 3000 0.0004770578541070344 -0.05
# var_PPV_lb_ub[0,7]_maxpower_profile_Puncertainty: 200.7440476190476 0.0 2850.0 3000 0.07043650793650794 -0.05
# var_PPV_lb_ub[0,8]_maxpower_profile_Puncertainty: 1100.824551131928 0.0 2850.0 3000 0.3862542284673432 -0.05
# var_PPV_lb_ub[0,9]_maxpower_profile_Puncertainty: 2022.5043911007026 0.0 2850.0 3000 0.7096506635441062 -0.05
# var_PPV_lb_ub[0,10]_maxpower_profile_Puncertainty: 2577.9534218058807 0.0 2850.0 3000 0.9045450602827652 -0.05
# var_PPV_lb_ub[0,11]_maxpower_profile_Puncertainty: 2850.0 0.0 2850.0 3000 1.0 -0.05
# var_PPV_lb_ub[0,12]_maxpower_profile_Puncertainty: 2847.1417187093416 0.0 2850.0 3000 0.9989970942839795 -0.05
# var_PPV_lb_ub[0,13]_maxpower_profile_Puncertainty: 2585.6785063752272 0.0 2850.0 3000 0.9072556162720097 -0.05
# var_PPV_lb_ub[0,14]_maxpower_profile_Puncertainty: 2274.048594847775 0.0 2850.0 3000 0.797911787665886 -0.05
# var_PPV_lb_ub[0,15]_maxpower_profile_Puncertainty: 1467.9669203747071 0.0 2850.0 3000 0.515076112412178 -0.05
# var_PPV_lb_ub[0,16]_maxpower_profile_Puncertainty: 657.6364493884985 0.0 2850.0 3000 0.23074963136438545 -0.05
# var_PPV_lb_ub[0,17]_maxpower_profile_Puncertainty: 71.75058548009368 0.0 2850.0 3000 0.025175644028103045 -0.05
# var_PPV_lb_ub[0,18]_maxpower_profile_Puncertainty: 9.455503512880563 0.0 2850.0 3000 0.003317720530835285 -0.05
# var_PPV_lb_ub[0,19]_maxpower_profile_Puncertainty: 6.210967993754879 0.0 2850.0 3000 0.0021792870153525892 -0.05
# var_PPV_lb_ub[0,20]_maxpower_profile_Puncertainty: 0.00285 0.0 2850.0 3000 1e-06 -0.05
# var_PPV_lb_ub[0,21]_maxpower_profile_Puncertainty: 0.26265287535779336 0.0 2850.0 3000 9.215890363431347e-05 -0.05
# var_PPV_lb_ub[0,22]_maxpower_profile_Puncertainty: 1.313264376788967 0.0 2850.0 3000 0.00046079451817156733 -0.05
# var_PPV_lb_ub[0,23]_maxpower_profile_Puncertainty: 1.2978142076502732 0.0 2850.0 3000 0.0004553734061930783 -0.05
# ***********
# ***********
# P_pv[i,step], lb, ub, max_power, profile, uncert
# var_PPV_lb_ub[1,0]_maxpower_profile_Puncertainty: 0.8034087952120739 0.0 1900.0 2000 0.00042284673432214416 -0.05
# var_PPV_lb_ub[1,1]_maxpower_profile_Puncertainty: 0.7725084569346864 0.0 1900.0 2000 0.0004065833983866771 -0.05
# var_PPV_lb_ub[1,2]_maxpower_profile_Puncertainty: 0.7107077803799116 0.0 1900.0 2000 0.0003740567265157429 -0.05
# var_PPV_lb_ub[1,3]_maxpower_profile_Puncertainty: 0.6901075548616532 0.0 1900.0 2000 0.00036321450255876484 -0.05
# var_PPV_lb_ub[1,4]_maxpower_profile_Puncertainty: 0.6798074421025241 0.0 1900.0 2000 0.0003577933905802758 -0.05
# var_PPV_lb_ub[1,5]_maxpower_profile_Puncertainty: 0.6901075548616532 0.0 1900.0 2000 0.00036321450255876484 -0.05
# var_PPV_lb_ub[1,6]_maxpower_profile_Puncertainty: 0.9064099228033654 0.0 1900.0 2000 0.0004770578541070344 -0.05
# var_PPV_lb_ub[1,7]_maxpower_profile_Puncertainty: 133.8293650793651 0.0 1900.0 2000 0.07043650793650794 -0.05
# var_PPV_lb_ub[1,8]_maxpower_profile_Puncertainty: 733.8830340879521 0.0 1900.0 2000 0.3862542284673432 -0.05
# var_PPV_lb_ub[1,9]_maxpower_profile_Puncertainty: 1348.3362607338017 0.0 1900.0 2000 0.7096506635441062 -0.05
# var_PPV_lb_ub[1,10]_maxpower_profile_Puncertainty: 1718.6356145372538 0.0 1900.0 2000 0.9045450602827652 -0.05
# var_PPV_lb_ub[1,11]_maxpower_profile_Puncertainty: 1900.0 0.0 1900.0 2000 1.0 -0.05
# var_PPV_lb_ub[1,12]_maxpower_profile_Puncertainty: 1898.0944791395611 0.0 1900.0 2000 0.9989970942839795 -0.05
# var_PPV_lb_ub[1,13]_maxpower_profile_Puncertainty: 1723.7856709168184 0.0 1900.0 2000 0.9072556162720097 -0.05
# var_PPV_lb_ub[1,14]_maxpower_profile_Puncertainty: 1516.0323965651833 0.0 1900.0 2000 0.797911787665886 -0.05
# var_PPV_lb_ub[1,15]_maxpower_profile_Puncertainty: 978.6446135831382 0.0 1900.0 2000 0.515076112412178 -0.05
# var_PPV_lb_ub[1,16]_maxpower_profile_Puncertainty: 438.4242995923323 0.0 1900.0 2000 0.23074963136438545 -0.05
# var_PPV_lb_ub[1,17]_maxpower_profile_Puncertainty: 47.83372365339578 0.0 1900.0 2000 0.025175644028103045 -0.05
# var_PPV_lb_ub[1,18]_maxpower_profile_Puncertainty: 6.3036690085870415 0.0 1900.0 2000 0.003317720530835285 -0.05
# var_PPV_lb_ub[1,19]_maxpower_profile_Puncertainty: 4.14064532916992 0.0 1900.0 2000 0.0021792870153525892 -0.05
# var_PPV_lb_ub[1,20]_maxpower_profile_Puncertainty: 0.0019 0.0 1900.0 2000 1e-06 -0.05
# var_PPV_lb_ub[1,21]_maxpower_profile_Puncertainty: 0.1751019169051956 0.0 1900.0 2000 9.215890363431347e-05 -0.05
# var_PPV_lb_ub[1,22]_maxpower_profile_Puncertainty: 0.8755095845259779 0.0 1900.0 2000 0.00046079451817156733 -0.05
# var_PPV_lb_ub[1,23]_maxpower_profile_Puncertainty: 0.8652094717668488 0.0 1900.0 2000 0.0004553734061930783 -0.05
# ***********
